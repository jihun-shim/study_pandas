# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### 기본 구성

# %%
x_data_first = [1,2,3,4]
y_data_first = [1,2,3,4]
x_data_second = [2,3,1,1]
y_data_second = [2,3,1,1]
x_data_third = [1,2,3,4]
y_data_third = [2,1,4,1]
x_data_fourth = [4,3,2,1]
y_data_fourth = [4,3,2,1]

# %% [markdown]
# ### 단일변수 표현

# %%
plt.plot(x_data_first) # 리스트로 저장되어 있기 때문에 단일변수 표현 즉 인덱스가 있기 때문
plt.show()

# %% [markdown]
# ### 다변수 표현

# %%
plt.plot(x_data_first, y_data_first)
plt.plot(y_data_third, x_data_third)

plt.show()

# %% [markdown]
# ### 설명 구성

# %%
plt.plot(x_data_first, y_data_first, label='x_data_legend') # 범례
plt.plot(y_data_third, x_data_third, label='y_data_legend')

plt.title('Visuallization With Title') #타이틀
plt.xlabel('x_data') # x축 레이블
plt.ylabel('y_data') # y축 레이블
plt.legend() 


plt.show()

# %% [markdown]
# #### 한글 처리

# %%
import matplotlib as mpl 
# 한글 폰트 설정 (NanumGothic) 
mpl.rcParams['font.family'] = 'NanumGothic'

# %%
plt.plot(x_data_first, y_data_first, label='x_data_범례') #범례
plt.plot(y_data_third, x_data_third, label='y_data_범례')

plt.title('Visuallization With 타이틀') #타이틀
plt.xlabel('x_데이터') # x축 레이블
plt.ylabel('y_데이터') # y축 레이블
plt.legend() #범례

plt.savefig('visualliztions_plots.png') # 장소 지정 및 저장할 형태
plt.show()

# %% [markdown]
# ### figure 넓이, 높이 조정

# %%
# plt.figure(figsize=(10,6)) # 10 * 6인치 # figure 넓이, 높이를 조정 단위는 인치
plt.figure(figsize=(10,6), dpi=100) # dpi 는 픽셀로 표현  

plt.plot(x_data_first, y_data_first, label='x_data_범례') #범례
plt.plot(y_data_third, x_data_third, label='y_data_범례')

plt.title('Visuallization With 타이틀') #타이틀
plt.xlabel('x_데이터') # x축 레이블
plt.ylabel('y_데이터') # y축 레이블
plt.legend() #범례

plt.savefig('visualliztions_plots.png') # 장소 지정 및 저장할 형태
plt.show()

# %% [markdown]
# #### 복수 컬럼 다루기

# %%
import pandas as pd

# %%
df_loan = pd.read_excel('../datasets/loan.xlsx', index_col=0, header=[0,1])

# %%
df_loan.iloc[0]
# Out:
# 전년동월비(%)기준년월
# 대출고객수         전체      7.1
#               1금융권    8.5
#               2금융권    5.9
# 대출잔액          전체      6.7
#               1금융권    9.8
#               2금융권    3.3
# Name: '21.06, dtype: float64

# %%
df_loan_fee = df_loan['대출잔액']
df_loan_fee
# Out:
#          전체  1금융권  2금융권
# '21.06  6.7   9.8   3.3
# '21.05  7.9  11.4   4.0
# '21.04  5.3   8.5   1.9
# '21.03  5.1   8.6   1.3
# '21.02  5.0   9.0   0.8
# '21.01  4.6   8.7   0.3
# '20.12  4.4   9.1  -0.4
# '20.11  4.2   8.8  -0.7
# '20.10  0.6   8.5  -7.2
# '20.09  2.1   6.6  -2.4
# '20.08  2.3   7.4  -2.7
# '20.07  2.0   6.9  -2.8
# '20.06  2.3   7.4  -2.7

# %%
df_loan_fee_sort = df_loan_fee[::-1]
df_loan_fee_sort
# Out:
#          전체  1금융권  2금융권
# '20.06  2.3   7.4  -2.7
# '20.07  2.0   6.9  -2.8
# '20.08  2.3   7.4  -2.7
# '20.09  2.1   6.6  -2.4
# '20.10  0.6   8.5  -7.2
# '20.11  4.2   8.8  -0.7
# '20.12  4.4   9.1  -0.4
# '21.01  4.6   8.7   0.3
# '21.02  5.0   9.0   0.8
# '21.03  5.1   8.6   1.3
# '21.04  5.3   8.5   1.9
# '21.05  7.9  11.4   4.0
# '21.06  6.7   9.8   3.3

# %%
df_loan_fee_sort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, '20.06 to '21.06
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   전체      13 non-null     float64
#  1   1금융권    13 non-null     float64
#  2   2금융권    13 non-null     float64
# dtypes: float64(3)
# memory usage: 416.0+ bytes

# %%
mpl.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
plt.plot(df_loan_fee_sort.index, df_loan_fee_sort['전체'], label='전체', marker='o') # marker 표시 
plt.plot(df_loan_fee_sort.index, df_loan_fee_sort['1금융권'], label='1금융권', marker='x')
plt.plot(df_loan_fee_sort.index, df_loan_fee_sort['2금융권'], label='2금융권', marker='+')
plt.legend()
plt.xticks(rotation=45) #아래 글자 기울기 조절 *눕힘으로써 겹침방지
plt.show()

# %%
df_loan_fee_sort.transpose() # 행과 열 바꾸기
# Out:
#       '20.06  '20.07  '20.08  '20.09  '20.10  '20.11  '20.12  '21.01  '21.02  \
# 전체       2.3     2.0     2.3     2.1     0.6     4.2     4.4     4.6     5.0
# 1금융권     7.4     6.9     7.4     6.6     8.5     8.8     9.1     8.7     9.0
# 2금융권    -2.7    -2.8    -2.7    -2.4    -7.2    -0.7    -0.4     0.3     0.8
#
#       '21.03  '21.04  '21.05  '21.06
# 전체       5.1     5.3     7.9     6.7
# 1금융권     8.6     8.5    11.4     9.8
# 2금융권     1.3     1.9     4.0     3.3

# %% [markdown]
# ### bar chart

# %%
first = [1,3,5,7,9]
second = [2,3,2,2,8]

# %%
plt.bar(first,second) # plt.bar *막대그래프
plt.show()
